# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("LiquorSales.csv")
data.head(10)
# Out:
# /tmp/ipykernel_753/2142152768.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("LiquorSales.csv")
#    Reference Invoice/Item Number    Invoice  Item Number     Date  \
# 0     167646         3.06831E+11  306831300           20  7/30/12
# 1     262366         3.06831E+11  306831300           15  7/30/12
# 2     794258         3.06831E+11  306831300            9  7/30/12
# 3      19508    4295S05259700026  4295S0525           26  4/26/12
# 4      64511    4295S05259700008  4295S0525            8  4/26/12
# 5      65917    4295S05259700032  4295S0525           32  4/26/12
# 6     262277    4295S05259700004  4295S0525            4  4/26/12
# 7     262740    4295S05259700001  4295S0525            1  4/26/12
# 8     339096    4295S05259700050  4295S0525           50  4/26/12
# 9     433545    4295S05259700039  4295S0525           39  4/26/12
#
#    Store Number        City Zip Code   County                   Category Name  \
# 0          3869  CORALVILLE    52241  Johnson                  VODKA 80 PROOF
# 1          3869  CORALVILLE    52241  Johnson                  VODKA FLAVORED
# 2          3869  CORALVILLE    52241  Johnson                  VODKA FLAVORED
# 3          4295  DES MOINES    50317     Polk               CANADIAN WHISKIES
# 4          4295  DES MOINES    50317     Polk                 100 PROOF VODKA
# 5          4295  DES MOINES    50317     Polk               CANADIAN WHISKIES
# 6          4295  DES MOINES    50317     Polk               AMERICAN DRY GINS
# 7          4295  DES MOINES    50317     Polk  DECANTERS & SPECIALTY PACKAGES
# 8          4295  DES MOINES    50317     Polk                  VODKA 80 PROOF
# 9          4295  DES MOINES    50317     Polk                  IMPORTED VODKA
#
#      Label                 Item Description  Pack  Bottle Volume (ml)  \
# 0    Vodka           Burnett's Vodka 80 Prf  12.0               750.0
# 1    Vodka                    Uv Cake Vodka  12.0               750.0
# 2    Vodka          Firefly Sweet Tea Vodka  12.0               750.0
# 3  Whiskey      Crown Royal Canadian Whisky  24.0               375.0
# 4    Vodka                  Mccormick Vodka  12.0               750.0
# 5  Whiskey             Canadian Club Whisky  12.0               750.0
# 6      Gin           Seagrams Extra Dry Gin  48.0               100.0
# 7  Novelty  Jagermeister Cocktail Glass Set  12.0               375.0
# 8    Vodka              New Amsterdam Vodka  12.0               750.0
# 9    Vodka     Absolut Swedish Vodka 80 Prf  24.0               375.0
#
#    Bottles Sold  Sale (Dollars)  Volume Sold (Liters)
# 0           1.0            6.82                  0.75
# 1           1.0            9.74                  0.75
# 2           1.0           14.00                  0.75
# 3           4.0           44.16                  1.50
# 4          12.0           59.52                  9.00
# 5           2.0           23.62                  1.50
# 6          48.0           70.08                  4.80
# 7          12.0          112.20                  4.50
# 8           2.0           20.70                  1.50
# 9           3.0           26.40                  1.12

# %%
data[['Month', 'Day', 'Year']] = data['Date'].str.split('/', expand = True)
data
# Out:
#        Reference Invoice/Item Number    Invoice  Item Number     Date  \
# 0         167646         3.06831E+11  306831300           20  7/30/12
# 1         262366         3.06831E+11  306831300           15  7/30/12
# 2         794258         3.06831E+11  306831300            9  7/30/12
# 3          19508    4295S05259700026  4295S0525           26  4/26/12
# 4          64511    4295S05259700008  4295S0525            8  4/26/12
# ...          ...                 ...        ...          ...      ...
# 68060      33143        S05087000007  S05087000            7  4/17/12
# 68061      70907        S05087000030  S05087000           30  4/17/12
# 68062      84142        S05087000057  S05087000           57  4/17/12
# 68063     129220        S05087000033  S05087000           33  4/17/12
# 68064     196807        S05087000014  S05087000           14  4/17/12
#
#        Store Number            City Zip Code         County  \
# 0              3869      CORALVILLE    52241        Johnson
# 1              3869      CORALVILLE    52241        Johnson
# 2              3869      CORALVILLE    52241        Johnson
# 3              4295      DES MOINES    50317           Polk
# 4              4295      DES MOINES    50317           Polk
# ...             ...             ...      ...            ...
# 68060          2641  COUNCIL BLUFFS    51501  Pottawattamie
# 68061          2641  COUNCIL BLUFFS    51501  Pottawattamie
# 68062          2641  COUNCIL BLUFFS    51501  Pottawattamie
# 68063          2641  COUNCIL BLUFFS    51501  Pottawattamie
# 68064          2641  COUNCIL BLUFFS    51501  Pottawattamie
#
#            Category Name    Label             Item Description  Pack  \
# 0         VODKA 80 PROOF    Vodka       Burnett's Vodka 80 Prf  12.0
# 1         VODKA FLAVORED    Vodka                Uv Cake Vodka  12.0
# 2         VODKA FLAVORED    Vodka      Firefly Sweet Tea Vodka  12.0
# 3      CANADIAN WHISKIES  Whiskey  Crown Royal Canadian Whisky  24.0
# 4        100 PROOF VODKA    Vodka              Mccormick Vodka  12.0
# ...                  ...      ...                          ...   ...
# 68060       FLAVORED RUM      Rum          Malibu Red PET Mini  12.0
# 68061     VODKA 80 PROOF    Vodka           Five O'clock Vodka  12.0
# 68062  AMERICAN AMARETTO  Liqueur           Paramount Amaretto  12.0
# 68063     VODKA 80 PROOF    Vodka                 Relska Vodka   6.0
# 68064             TEQUIL      NaN                          NaN   NaN
#
#        Bottle Volume (ml)  Bottles Sold  Sale (Dollars)  Volume Sold (Liters)  \
# 0                   750.0           1.0            6.82                  0.75
# 1                   750.0           1.0            9.74                  0.75
# 2                   750.0           1.0           14.00                  0.75
# 3                   375.0           4.0           44.16                  1.50
# 4                   750.0          12.0           59.52                  9.00
# ...                   ...           ...             ...                   ...
# 68060               502.0          12.0           59.40                  6.02
# 68061              1000.0          12.0           72.12                 12.00
# 68062               750.0          12.0           60.72                  9.00
# 68063              1750.0           6.0           64.50                 10.50
# 68064                 NaN           NaN             NaN                   NaN
#
#       Day Month Year
# 0      30     7   12
# 1      30     7   12
# 2      30     7   12
# 3      26     4   12
# 4      26     4   12
# ...    ..   ...  ...
# 68060  17     4   12
# 68061  17     4   12
# 68062  17     4   12
# 68063  17     4   12
# 68064  17     4   12
#
# [68065 rows x 20 columns]

# %%
data['Month'].unique()
# Out:
# array(['7', '4', '1', '2', '3'], dtype=object)

# %%
# Q1: What time of year are liquor sales the highest?

def timeofyear_maximum(filename, Time, Sales):
    data = pd.read_csv(filename)
    data[['Month', 'Day', 'Year']] = data['Date'].str.split('/', expand = True)
    data = data.groupby(data[Time])
    
    max_of_col = data[Sales].max() 
    return max_of_col

print(timeofyear_maximum('LiquorSales.csv', 'Month', 'Sale (Dollars)'))
print(timeofyear_maximum('LiquorSales.csv', 'Year', 'Sale (Dollars)'))
# Out:
# /tmp/ipykernel_753/3771665837.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filename)
# Month
# 1    12840.00
# 2    25584.00
# 3    23478.00
# 4    20515.20
# 7      323.88
# Name: Sale (Dollars), dtype: float64
# /tmp/ipykernel_753/3771665837.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filename)
# Year
# 12    25584.00
# 13      323.88
# Name: Sale (Dollars), dtype: float64

# %%
# Are there hotspots where liquor sales are higher than average

def county_maximum(filename, County, Sales):
    data = pd.read_csv(filename)
    data[['Month', 'Day', 'Year']] = data['Date'].str.split('/', expand = True)
    data = data.groupby(data[County])
    max_of_col = data[Sales].max() 
    return max_of_col

def county_mean(filename, County, Sales):
    data = pd.read_csv(filename)
    data[['Month', 'Day', 'Year']] = data['Date'].str.split('/', expand = True)
    data = data.groupby(data[County])
    mean_of_col = data[Sales].mean() 
    return mean_of_col.sort_values()
    # max_avg, min_avg = mean_of_col.max(), mean_of_col.min()
    # return max_avg, min_avg

def state_mean(filename, Sales):
    data = pd.read_csv(filename)
    mean_of_col = data[Sales].mean() 
    return mean_of_col


# print(county_maximum('LiquorSales.csv', 'County', 'Sale (Dollars)'))
# print(county_maximum('LiquorSales.csv', 'City', 'Sale (Dollars)'))
print(county_mean('LiquorSales.csv', 'County', 'Sale (Dollars)'))
print(county_mean('LiquorSales.csv', 'City', 'Sale (Dollars)'))
print(state_mean('LiquorSales.csv', 'Sale (Dollars)'))

## Reminder: Taylor county has lowest average liqour sales overall, Dallas county has highest average liquor sales overall.
## Reminder: West Branch city has lowest average liqour sales overall, Le Claire city has highest average liquor sales overall.
# Out:
# /tmp/ipykernel_753/451713942.py:11: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filename)
# County
# Taylor       35.707037
# Greene       36.278805
# Wayne        38.568790
# Cedar        39.016274
# Louisa       41.207677
#                ...
# Henry       152.054225
# Humboldt    188.674202
# Delaware    192.461765
# Howard      207.398374
# Dallas      272.945000
# Name: Sale (Dollars), Length: 99, dtype: float64
# /tmp/ipykernel_753/451713942.py:11: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filename)
# City
# WEST BRANCH         20.716196
# WILTON              21.811163
# BLUE GRASS          22.033889
# DURANT              22.730385
# STATE CENTER        23.825333
#                       ...
# VINTON             223.570476
# PALO               238.080000
# WEST BURLINGTON    239.335814
# WINDSOR HEIGHTS    273.943662
# LECLAIRE           376.020000
# Name: Sale (Dollars), Length: 329, dtype: float64
# 114.04583024800189
# /tmp/ipykernel_753/451713942.py:20: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filename)

# %%
## Is there a preferred liquor type by county or city

def preferred_type(filename, Liquor):
    data = pd.read_csv(filename)
    data = data.groupby(data[Liquor])['Reference'].count()
    return data


def preferred_type_byLoc(filename, Liquor, Location):
    data = pd.read_csv(filename)
    data = data.groupby([Location, Liquor])['Reference'].count()
    return data
    
print(preferred_type('LiquorSales.csv', 'Label'))
print(preferred_type_byLoc('LiquorSales.csv', 'Label', 'County'))
print(preferred_type_byLoc('LiquorSales.csv', 'Label', 'City'))
# Out:
# /tmp/ipykernel_753/1153938833.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filename)
# /tmp/ipykernel_753/1153938833.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filename)
# Label
# Bourbon                 3790
# Brandy                  3715
# Cream Based Liqueur     1430
# Gin                     2845
# Liqueur                 6888
# Novelty                   58
# Other Grain Alcohol      284
# Pre-Mixed Cocktails     2319
# Rum                     8711
# Schnapps                4792
# Scotch                   514
# Tequila                 3081
# Vodka                  16810
# Whiskey                12827
# Name: Reference, dtype: int64
# County  Label
# Adair   Bourbon                10
#         Brandy                  9
#         Cream Based Liqueur     5
#         Gin                     5
#         Liqueur                 9
#                                ..
# Wright  Rum                    34
#         Schnapps               17
#         Tequila                 9
#         Vodka                  42
#         Whiskey                67
# Name: Reference, Length: 1225, dtype: int64
# City             Label
# ACKLEY           Bourbon    1
#                  Brandy     2
#                  Liqueur    1
#                  Rum        5
#                  Vodka      2
#                            ..
# WOODWARD         Rum        2
#                  Vodka      3
# Windsor Heights  Rum        3
#                  Vodka      3
#                  Whiskey    2
# Name: Reference, Length: 3028, dtype: int64
# /tmp/ipykernel_753/1153938833.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filename)

# %%
## Time of year when liquor sales go up

monthly_sales = timeofyear_maximum('LiquorSales.csv', 'Month', 'Sale (Dollars)')

monthly_sales.plot();
# Out:
# /tmp/ipykernel_753/3771665837.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(filename)

# %%
# df = pd.read_csv('LiquorSales.csv')
# df[['Month', 'Day', 'Year']] = data['Date'].str.split('/', expand = True)
# df.sort_values(["Month"], axis=0,ascending=[True], inplace=True)


# plt.figure(figsize=(16, 8), dpi=150)
  
# # using plot method to plot open prices.
# # in plot method we set the label and color of the curve.
# df['Month'].plot(label='Month', color='orange')
# df['Sale (Dollars)'].plot(label='Sales')

  
# # adding title to the plot
# plt.title('Monthly Liquor Sales')
  
# # adding Label to the x-axis
# plt.xlabel('Month')
  
# # adding legend to the curve
# plt.legend()
# plt.show()
